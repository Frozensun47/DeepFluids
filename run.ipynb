# %%
# !python train.py --test_data Fluid-Flow-Prediction-on-Airplanes-with-Machine-Learning-main\DataSet1_Q --train_data Fluid-Flow-Prediction-on-Airplanes-with-Machine-Learning-main\DataSet2_Q --epochs 100 --learning_rate 0.001 --hidden_units 256 128 64 32 --model_load_dir Models\my_model.h5
# Out:
# Model Loaded
# Epoch 1/100
#
# ...
# 4663/4693 [============================>.] - ETA: 0s - loss: 1188.7302
# Epoch 1: val_loss improved from inf to 1307.92065, saving model to best_model.hdf5
#
# 4693/4693 [==============================] - 8s 2ms/step - loss: 1189.0756 - val_loss: 1307.9207 - lr: 2.0000e-04
# Epoch 2/100
#
# ...
# 4675/4693 [============================>.] - ETA: 0s - loss: 1185.9625
# Epoch 2: val_loss did not improve from 1307.92065
#
# 4693/4693 [==============================] - 9s 2ms/step - loss: 1185.9119 - val_loss: 1356.1024 - lr: 2.0000e-04
# Epoch 3/100
#
# ...
# 4678/4693 [============================>.] - ETA: 0s - loss: 1186.8584
# Epoch 3: val_loss did not improve from 1307.92065
#
# 4693/4693 [==============================] - 8s 2ms/step - loss: 1186.9500 - val_loss: 1324.1007 - lr: 2.0000e-04
# Epoch 4/100
#
# ...
# 4664/4693 [============================>.] - ETA: 0s - loss: 1185.7626
# Epoch 4: val_loss did not improve from 1307.92065
#
# ...

# %%
# !python test.py --test_data Fluid-Flow-Prediction-on-Airplanes-with-Machine-Learning-main\DataSet2_Q --load_model Models\my_model.h5
# Out:
# 11731/11731 - 10s - loss: 1292.4783 - 10s/epoch - 828us/step
# Test loss: 1292.478271484375
#
# ...
# 11731/11731 [==============================] - 9s 793us/step
# 2023-08-20 20:47:38.985611: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-20 20:47:38.987150: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Traceback (most recent call last):
#   File "c:\Users\sagar\Documents\MY-PROJECTS\Fluid-Flow-Prediction-on-Airplanes-with-Machine-Learning-main\test.py", line 49, in <module>
#     rmse, precision, recall, f1 = calculate_metrics(y_test, test_predictions)
# ...

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []
